# %%
import czifile
from IPython.display import Image
from PIL import Image # con Pil se puede abrir imagenes en formato tif
from IPython.display import Video
import matplotlib 
import numpy

# %%
import tifffile

# %%
from skimage.io import imread

# %%
from czifile import CziFile

# %%
img=Image.open("celulas.tif") 
display(img)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=372x289 at 0x188F863EA20>

# %%
image = imread('celulas.tif')

# %%
image.shape
# Out:
# (289, 372, 3)

# %%
image[0, 0, 0]
# Out:
# 18

# %%
#imageczi = imread('test2.czi')

# %%
with CziFile('test2.czi') as czi:
    image_arrays = czi.asarray()

# %%
image_arrays.shape
# Out:
# (1, 1, 1, 60, 17, 880, 836, 1)
